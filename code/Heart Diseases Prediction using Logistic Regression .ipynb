# %% [markdown]
# # Exp 2.1 Heart Disease Prediction using Logistic Regression

# %% [markdown]
# i) import Libraries and Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
hd=pd.read_csv("heart.csv")

# %%
hd
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63       1   3       145   233    1        0      150      0      2.3
# 1     37       1   2       130   250    0        1      187      0      3.5
# 2     41       0   1       130   204    0        0      172      0      1.4
# 3     56       1   1       120   236    0        1      178      0      0.8
# 4     57       0   0       120   354    0        1      163      1      0.6
# ..   ...     ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57       0   0       140   241    0        1      123      1      0.2
# 299   45       1   3       110   264    0        1      132      0      1.2
# 300   68       1   0       144   193    1        1      141      0      3.4
# 301   57       1   0       130   131    0        1      115      1      1.2
# 302   57       0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# ...

# %% [markdown]
# # If i want only 5 rows or last 5

# %%
hd.head()
# Out:
#    age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63       1   3       145   233    1        0      150      0      2.3
# 1   37       1   2       130   250    0        1      187      0      3.5
# 2   41       0   1       130   204    0        0      172      0      1.4
# 3   56       1   1       120   236    0        1      178      0      0.8
# 4   57       0   0       120   354    0        1      163      1      0.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# 4      2   0     2       1

# %%
hd.tail()
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57       0   0       140   241    0        1      123      1      0.2
# 299   45       1   3       110   264    0        1      132      0      1.2
# 300   68       1   0       144   193    1        1      141      0      3.4
# 301   57       1   0       130   131    0        1      115      1      1.2
# 302   57       0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
hd.head(10)
# Out:
#    age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63       1   3       145   233    1        0      150      0      2.3
# 1   37       1   2       130   250    0        1      187      0      3.5
# 2   41       0   1       130   204    0        0      172      0      1.4
# 3   56       1   1       120   236    0        1      178      0      0.8
# 4   57       0   0       120   354    0        1      163      1      0.6
# 5   57       1   0       140   192    0        1      148      0      0.4
# 6   56       0   1       140   294    0        0      153      0      1.3
# 7   44       1   1       120   263    0        1      173      0      0.0
# 8   52       1   2       172   199    1        1      162      0      0.5
# 9   57       1   2       150   168    0        1      174      0      1.6
#
#    slope  ca  thal  target
# 0      0   0     1       1
# 1      0   0     2       1
# 2      2   0     2       1
# 3      2   0     2       1
# ...

# %%
hd.tail(10)
# Out:
#      age  gender  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 293   67       1   2       152   212    0        0      150      0      0.8
# 294   44       1   0       120   169    0        1      144      1      2.8
# 295   63       1   0       140   187    0        0      144      1      4.0
# 296   63       0   0       124   197    0        1      136      1      0.0
# 297   59       1   0       164   176    1        0       90      0      1.0
# 298   57       0   0       140   241    0        1      123      1      0.2
# 299   45       1   3       110   264    0        1      132      0      1.2
# 300   68       1   0       144   193    1        1      141      0      3.4
# 301   57       1   0       130   131    0        1      115      1      1.2
# 302   57       0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 293      1   0     3       0
# 294      0   0     1       0
# 295      2   2     3       0
# ...

# %% [markdown]
# ii) Data Wrangling

# %%
#No. of Rows and No. of Colum in a Dataset
hd.shape
# Out:
# (303, 14)

# %%
#Information about datset
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   gender    303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
hd.isnull().sum()
# Out:
# age         0
# gender      0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#Statistical Measures of Dataset
hd.describe()
# Out:
#               age      gender          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
#1- having Heart diseases #0- not having
hd['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
#splitting the features and Targets (y is output) 
x = hd.drop(columns='target',axis=1)
y = hd.target

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %% [markdown]
# iii) Data Visualization

# %%
sns.countplot(x='gender',data=hd )
plt.xlabel("Gender(0=Female,1=Male)")
plt.show()

# %%
#how the age is distributed in data set(Heart Diseases Frequency for ages)
pd.crosstab(hd.age,hd.target).plot(kind="bar",figsize=(10,6))
plt.title('Heart Diseases Frequency for Ages')
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.savefig('Heart_Disease_and_ages.png')
plt.show()

# %%
# Heart Disease Freqency for Gender
pd.crosstab(hd.gender,hd.target).plot(kind="bar",figsize=(10,6), color=['#1CA53B','#AA1111'])
plt.title('Heart Diseases Frequency for Gender')
plt.xlabel("Gender(0=Female,1=Male)")
plt.legend(["Haven't Diseases","have Disease"])
plt.ylabel("Frequency")
plt.savefig('Heart_Disease_and_Gender.png')
plt.show()

# %% [markdown]
# iv) Splitting the Data into Training and Testing Data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %% [markdown]
# v)Logistic Regression Model

# %%
model=linear_model.LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # vi)Model evaluation for Accuracy Score

# %% [markdown]
#     i)Accuracy on Training Data

# %%
x_train_prediction=model.predict(x_train)
training_data_accuracy= accuracy_score(x_train_prediction,y_train)
print("Accuracy on Training Data :",training_data_accuracy)
# Out:
# Accuracy on Training Data : 0.8512396694214877

# %% [markdown]
#         ii) Accuracy on Testing data

# %%
x_test_prediction=model.predict(x_test)
testing_data_accuracy= accuracy_score(x_test_prediction,y_test)
print("Accuracy on Testing Data :",testing_data_accuracy)
# Out:
# Accuracy on Testing Data : 0.819672131147541

# %% [markdown]
# # vii) Build Predictive System

# %%
input_data=(41,0,1,130,204,0,0,172,0,1,4,2,0,2)

#Change the input data to a numpy array 
input_data_as_numpy_array=np.asarray(input_data)

#Reshaping the numpy array as we are predictive for only on Instance
input_data_reshaped= input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if(prediction[0] ==0):
    print("The person does NOT have a Heart Disease")
else:
    print("The person have a Heart Disease")
